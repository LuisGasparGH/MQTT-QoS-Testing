# %%
from matplotlib import pyplot

bar_width = 0.4
legend_1clients = pyplot.Rectangle((0,0), 1, 1, fc='blue')
legend_2clients = pyplot.Rectangle((0,0), 1, 1, fc='lightgreen')
legend_5clients = pyplot.Rectangle((0,0), 1, 1, fc='orange')
legend_10clients = pyplot.Rectangle((0,0), 1, 1, fc='red')

# %%
loss_fig = pyplot.figure(figsize=(10,10))
loss_axis = loss_fig.add_subplot(111, projection='3d')
loss_axis.set_xlim([0,4])
loss_axis.set_ylim([0,4])
loss_axis.set_zlim([0,4])
loss_axis.set_title('Packet Loss (Average)', fontsize=20, fontweight='bold')
loss_axis.set_xlabel('QoS Level')
loss_axis.set_ylabel('Payload Size (KB)')
loss_axis.set_zlabel('Packet Loss (%)')
loss_axis.set_xticks(ticks=[0.45,1.95,3.45], labels=['2','1','0'])
loss_axis.set_yticks(ticks=[0.575,2.075,3.575], labels=['1.25', '12.5', '125'])
loss_axis.legend([legend_1clients, legend_2clients, legend_5clients, legend_10clients], ['1 Client', '2 Clients', '5 Clients', '10 Clients'])

# bar3d(x start, y start, z start, x length, y length, z length)
x_start = 0.0
y_start = 0.0
z_start = 0.0
loss_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
loss_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
loss_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
loss_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

x_start = 1.5
loss_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
loss_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
loss_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
loss_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

x_start = 3.0
loss_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
loss_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
loss_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
loss_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

x_start = 0.0
y_start = 1.5
loss_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
loss_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
loss_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
loss_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

x_start = 1.5
loss_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
loss_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
loss_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
loss_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

x_start = 3.0
loss_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
loss_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
loss_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
loss_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

x_start = 0.0
y_start = 3.0
loss_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
loss_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
loss_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
loss_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

x_start = 1.5
loss_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
loss_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
loss_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
loss_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

x_start = 3.0
loss_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
loss_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
loss_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
loss_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

pyplot.savefig('3DFigs/loss_fig.svg')

# %%
timefactor_fig = pyplot.figure(figsize=(10,10))
timefactor_axis = timefactor_fig.add_subplot(111, projection='3d')
timefactor_axis.set_xlim([0,4])
timefactor_axis.set_ylim([0,4])
timefactor_axis.set_zlim([0,4])
timefactor_axis.set_title('Time Factor (Average)', fontsize=20, fontweight='bold')
timefactor_axis.set_xlabel('Publish Frequency (Hz)')
timefactor_axis.set_ylabel('Payload Size (KB)')
timefactor_axis.set_zlabel('Time Factor (x)')
timefactor_axis.set_xticks(ticks=[0.45,1.95,3.45], labels=['50','25','5'])
timefactor_axis.set_yticks(ticks=[0.575,2.075,3.575], labels=['1.25', '12.5', '125'])
timefactor_axis.legend([legend_1clients, legend_2clients, legend_5clients, legend_10clients], ['1 Client', '2 Clients', '5 Clients', '10 Clients'])

# bar3d(x start, y start, z start, x length, y length, z length)
x_start = 0.0
y_start = 0.0
z_start = 0.0
timefactor_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
timefactor_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
timefactor_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
timefactor_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

x_start = 1.5
timefactor_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
timefactor_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
timefactor_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
timefactor_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

x_start = 3.0
timefactor_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
timefactor_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
timefactor_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
timefactor_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

x_start = 0.0
y_start = 1.5
timefactor_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
timefactor_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
timefactor_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
timefactor_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

x_start = 1.5
timefactor_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
timefactor_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
timefactor_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
timefactor_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

x_start = 3.0
timefactor_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
timefactor_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
timefactor_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
timefactor_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

x_start = 0.0
y_start = 3.0
timefactor_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
timefactor_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
timefactor_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
timefactor_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

x_start = 1.5
timefactor_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
timefactor_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
timefactor_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
timefactor_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

x_start = 3.0
timefactor_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
timefactor_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
timefactor_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
timefactor_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

pyplot.savefig('3DFigs/timefactor_fig.svg')

# %%
ooo_fig = pyplot.figure(figsize=(10,10))
ooo_axis = ooo_fig.add_subplot(111, projection='3d')
ooo_axis.set_xlim([0,4])
ooo_axis.set_ylim([0,4])
ooo_axis.set_zlim([0,4])
ooo_axis.set_title('Out of Order Messages (Average)', fontsize=20, fontweight='bold')
ooo_axis.set_xlabel('Message Queue Size (#)')
ooo_axis.set_ylabel('Payload Size (KB)')
ooo_axis.set_zlabel('Out of Order Messages (#)')
ooo_axis.set_xticks(ticks=[0.45,1.95,3.45], labels=['1000','100','10'])
ooo_axis.set_yticks(ticks=[0.575,2.075,3.575], labels=['1.25', '12.5', '125'])
ooo_axis.legend([legend_1clients, legend_2clients, legend_5clients, legend_10clients], ['1 Client', '2 Clients', '5 Clients', '10 Clients'])

# bar3d(x start, y start, z start, x length, y length, z length)
x_start = 0.0
y_start = 0.0
z_start = 0.0
ooo_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
ooo_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
ooo_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
ooo_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

x_start = 1.5
ooo_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
ooo_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
ooo_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
ooo_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

x_start = 3.0
ooo_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
ooo_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
ooo_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
ooo_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

x_start = 0.0
y_start = 1.5
ooo_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
ooo_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
ooo_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
ooo_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

x_start = 1.5
ooo_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
ooo_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
ooo_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
ooo_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

x_start = 3.0
ooo_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
ooo_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
ooo_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
ooo_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

x_start = 0.0
y_start = 3.0
ooo_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
ooo_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
ooo_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
ooo_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

x_start = 1.5
ooo_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
ooo_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
ooo_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
ooo_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

x_start = 3.0
ooo_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
ooo_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
ooo_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
ooo_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

pyplot.savefig('3DFigs/ooo_fig.svg')

# %%
rtt_fig = pyplot.figure(figsize=(10,10))
rtt_axis = rtt_fig.add_subplot(111, projection='3d')
rtt_axis.set_xlim([0,4])
rtt_axis.set_ylim([0,4])
rtt_axis.set_zlim([0,4])
rtt_axis.set_title('RTT (Average)', fontsize=20, fontweight='bold')
rtt_axis.set_xlabel('QoS Level')
rtt_axis.set_ylabel('Payload Size (KB)')
rtt_axis.set_zlabel('RTT (ms)')
rtt_axis.set_xticks(ticks=[0.45,1.95,3.45], labels=['2','1','0'])
rtt_axis.set_yticks(ticks=[0.575,2.075,3.575], labels=['1.25', '12.5', '125'])
rtt_axis.legend([legend_1clients, legend_2clients, legend_5clients, legend_10clients], ['1 Client', '2 Clients', '5 Clients', '10 Clients'])

# bar3d(x start, y start, z start, x length, y length, z length)
x_start = 0.0
y_start = 0.0
z_start = 0.0
rtt_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
rtt_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
rtt_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
rtt_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

x_start = 1.5
rtt_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
rtt_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
rtt_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
rtt_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

x_start = 3.0
rtt_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
rtt_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
rtt_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
rtt_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

x_start = 0.0
y_start = 1.5
rtt_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
rtt_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
rtt_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
rtt_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

x_start = 1.5
rtt_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
rtt_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
rtt_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
rtt_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

x_start = 3.0
rtt_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
rtt_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
rtt_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
rtt_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

x_start = 0.0
y_start = 3.0
rtt_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
rtt_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
rtt_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
rtt_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

x_start = 1.5
rtt_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
rtt_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
rtt_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
rtt_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

x_start = 3.0
rtt_axis.bar3d(x_start, y_start, z_start, bar_width, bar_width, 0, shade=True, color='blue')
rtt_axis.bar3d(x_start, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='lightgreen')
rtt_axis.bar3d(x_start+0.6, y_start, z_start, bar_width, bar_width, 0, shade=True, color='orange')
rtt_axis.bar3d(x_start+0.6, y_start+0.6, z_start, bar_width, bar_width, 0, shade=True, color='red')

pyplot.savefig('3DFigs/rtt_fig.svg')
